# %% [markdown]
# # Predict whether the internship is real or fake

# %%
import pandas as pd

# %%
df=pd.read_csv('Fake_Internship_Detection.csv')
df
# Out:
#    PaymentRequired  CertificateGuaranteed  ContactEmail  Result
# 0                1                      1             0       1
# 1                1                      0             0       1
# 2                0                      1             0       1
# 3                0                      0             1       0
# 4                0                      0             1       0
# 5                1                      1             1       1
# 6                0                      0             0       0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.PaymentRequired,df.Result)

# %%
plt.scatter(df.CertificateGuaranteed,df.Result)

# %%
plt.scatter(df.ContactEmail,df.Result)

# %%
plt.plot(df.CertificateGuaranteed,df.Result)

# %%
plt.plot(df.ContactEmail,df.Result)

# %%
plt.plot(df.PaymentRequired,df.Result)

# %%
from sklearn import linear_model

# %%
reg=linear_model.LogisticRegression()

# %%
reg
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df[['PaymentRequired','ContactEmail','CertificateGuaranteed']],df[['Result']])

# %%
X_train
# Out:
#    PaymentRequired  ContactEmail  CertificateGuaranteed
# 4                0             1                      0
# 0                1             0                      1
# 3                0             1                      0
# 5                1             1                      1
# 6                0             0                      0

# %%
X_test
# Out:
#    PaymentRequired  ContactEmail  CertificateGuaranteed
# 2                0             0                      1
# 1                1             0                      0

# %%
Y_train
# Out:
#    Result
# 4       0
# 0       1
# 3       0
# 5       1
# 6       0

# %%
Y_test
# Out:
#    Result
# 2       1
# 1       1

# %%
reg.fit(X_train,Y_train)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([0, 0])

# %%
reg.predict([[1,0,1]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[0, 0],
#        [2, 0]])

# %%
from sklearn.metrics import classification_report

# %%
cr=classification_report(Y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00       2.0
#
#     accuracy                           0.00       2.0
#    macro avg       0.00      0.00      0.00       2.0
# weighted avg       0.00      0.00      0.00       2.0
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
