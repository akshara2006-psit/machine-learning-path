# %%
f=open('new.txt')
f.read()
f.close()

# %%
f=open('new.txt')
f.read()
f.close()

# %%
f=open('new.txt','w')
f.write("I am very sensitive")
f.close()

# %%
f=open('new.txt','a+')
f.write("I love solving mathematical problems")
f.close()

# %%
f=open('new.txt','r')
f.read()
# Out:
# 'I am very sensitiveI love solving mathematical problems'
