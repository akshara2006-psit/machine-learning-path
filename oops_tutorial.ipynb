# %% [markdown]
# ##                                OOPS Tutorial in Python

# %%
class Car:
    pass       #defining a class

# %%
Car1=Car()     #making objects of class Car

# %%
Car1

# %%
Car1.window=5
Car1.door=4

# %%
Car2=Car()

# %%
print(Car1.window)
# Out:
# 5

# %%
Car2.window=3
Car2.doors=2

# %%
print(Car2.window)
# Out:
# 3

# %%
class Car:
    def __init__(self,window,door,enginetype):
        self.windows=window
        self.doors=door
        self.enginetype=enginetype

# %%
Car1=Car()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Car1=Car()
#
# TypeError: Car.__init__() missing 3 required positional arguments: 'window', 'door', and 'enginetype'
