# %%
from tkinter import Tk,label
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from tkinter import Tk,label
#
# ImportError: cannot import name 'Tk' from 'tkinter' (C:\Users\HP\machine learning playlist\tkinter.py)

# %%
root=Tk()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 root=Tk()
#
# NameError: name 'Tk' is not defined

# %%
from tkinter import Tk, Label

root = Tk()
root.title("Test Window")
Label(root, text="Hello, Akshara!").pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from tkinter import Tk, Label
#       3 root = Tk()
#       4 root.title("Test Window")
#
# ImportError: cannot import name 'Tk' from 'tkinter' (C:\Users\HP\machine learning playlist\tkinter.py)

# %%
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 root.mainloop()
#
# NameError: name 'root' is not defined
