# %%
my_str="Akshara Gupta"

# %%
print(my_str.isalnum())
# Out:
# False

# %%
print(my_str.isalpha())
# Out:
# False

# %%
print(my_str.isdigit())
# Out:
# False

# %%
print(my_str.istitle())
# Out:
# True

# %%
print(my_str.isupper())
# Out:
# False

# %%
print(my_str.islower())
# Out:
# False

# %%
print(my_str.endswith('a'))
# Out:
# True

# %%
print(my_str.startswith('K'))
# Out:
# False

# %%
lst=list()

# %%
type(lst)
# Out:
# list

# %%
lst.append("mathematics")
# append function add element at the last index

# %%
lst
# Out:
# ['mathematics']

# %%
# insert in aspecific order
lst.insert(0,"english")

# %%
lst
# Out:
# ['english', 'mathematics']

# %%
lst.append(["social science","chemistry"])

# %%
lst
# Out:
# ['english', 'mathematics', ['social science', 'chemistry']]

# %% [markdown]
# ## extend method

# %%
lst.extend([6,7])

# %%
lst
# Out:
# ['english', 'mathematics', ['social science', 'chemistry'], 6, 7]

# %% [markdown]
# ## Various operations that we can perform in list

# %%
lst=[1,2,3,4,5]

# %%
sum(lst)
# Out:
# 15

# %%
lst.pop()
# Out:
# 5

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
lst=[1,1,3,21,4,51,5]
lst.count(1)  #calculate the total occurence of given element of List
# Out:
# 2

# %%
len(lst)  #calculates the total length of list
# Out:
# 7

# %%
# index():returns the index of first occurence start and end index are not neccessary parameters
lst.index(1,0,4)
# Out:
# 0

# %%
# min and max
# min return minimum value of the list
# max return maximum value of the list

# %%
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 51

# %%
set_var=set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
set_var={"Avengers","Ironman","Hitman"}
print(set_var)
type(set_var)
# Out:
# {'Avengers', 'Hitman', 'Ironman'}
# set

# %%
#indexing:set does not support indexing so it throws error
set_var[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 #indexing:set does not support indexing so it throws error
# ----> 2 set_var[0]
#
# TypeError: 'set' object is not subscriptable

# %%
set_var.add("Hulk")
set_var
# Out:
# {'Avengers', 'Hitman', 'Hulk', 'Ironman'}

# %% [raw]
# # difference
# set1={"Avengers","ironman","hitman"}
# set2={"Avengers","ironman","hitman","hulk2"}
# set2.difference(set1)

# %%
set2.intersection(set1)
# Out:
# {'Avengers', 'hitman', 'ironman'}

# %%
set2.union(set1)
# Out:
# {'Avengers', 'hitman', 'hulk2', 'ironman'}

# %% [markdown]
# # Dictionary

# %% [markdown]
# a dictionary is acollection of unordered,changeable and indexed,it is written with curly brackets,and they ahave keys and values

# %%
dic={}
type(dic)
# Out:
# dict

# %%
dic={1,2,3,4,5}
type(dic)
# Out:
# set

# %%
# lets create a dictionary
my_dict={"car1":"audi","car2":"bmw","car3":"merecedes"}
type(my_dict)
# Out:
# dict

# %% [markdown]
# ## Nested Dictionary

# %%
car1_model={'Mercedes':1960}
car2_model={'Audi':1970}
car3_model={'Ambassador':1980}

car_type={'car1':car1_model,'car2':car2_model,'car3':car3_model}

# %%
print(car_type)
# Out:
# {'car1': {'Mercedes': 1960}, 'car2': {'Audi': 1970}, 'car3': {'Ambassador': 1980}}

# %% [markdown]
# # TUPLES

# %%
# create an empty tuples
my_tuple=tuple()

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple=()
type(my_tuple)
# Out:
# tuple

# %%
my_tuple=("krish","ankur","john")
my_tuple[0]
# Out:
# 'krish'

# %%
my_tuple[0]='akshara'  # it gives error tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 my_tuple[0]='akshara'
#
# TypeError: 'tuple' object does not support item assignment
