# %% [markdown]
# # Salary prediction by experience

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("experience_vs_salary_pred.csv")
df
# Out:
#    Experience  Salary
# 0         0.5     1.2
# 1         1.0     1.8
# 2         2.0     2.5
# 3         3.0     3.2
# 4         4.0     4.0
# 5         5.0     4.8
# 6         6.0     5.5
# 7         7.0     6.2
# 8         8.0     7.0
# 9         9.0     7.8

# %%
plt.scatter(df['Experience'],df['Salary'])

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,y_test=train_test_split(df[['Experience']],df[['Salary']],test_size=0.2)

# %%
X_test
# Out:
#    Experience
# 4         4.0
# 7         7.0

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([[3.98696983],
#        [6.27205947]])

# %%
reg.score(X_test,y_test)
# Out:
# 0.9977841520398774

# %%
reg.predict([[6.5]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5.89121119]])

# %%
reg.predict([[2]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.46357674]])

# %%
reg.predict([[-1]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.1784871]])
