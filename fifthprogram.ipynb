# %% [markdown]
# # Spliting the dataset into two parts

# %%
import pandas as pd

# %%
df=pd.read_csv("carpred2.csv")
df
# Out:
#    Mileage  Age  SellPrice
# 0    69000    6      18000
# 1    35000    3      34000
# 2    57000    5      26100
# 3    22500    2      40000
# 4    46000    4      31500
# 5    59000    5      26750
# 6    52000    5      32000
# 7    72000    6      19300
# 8    91000    8      12000
# 9    67000    6      22000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Car Mileage Vs Sell Price

# %%
plt.scatter(df['Mileage'],df['SellPrice'])

# %% [markdown]
# ## Car age vs sell price

# %%
plt.scatter(df['Age'],df['SellPrice'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df[['Mileage','Age']],df['SellPrice'],test_size=0.2,random_state=10)

# %%
len(X_train)
# Out:
# 8

# %%
X_train
# Out:
#    Mileage  Age
# 4    46000    4
# 1    35000    3
# 8    91000    8
# 0    69000    6
# 5    59000    5
# 2    57000    5
# 7    72000    6
# 9    67000    6

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([12325.79413829, 26257.13408213])

# %%
Y_test
# Out:
# 8    12000
# 2    26100
# Name: SellPrice, dtype: int64
