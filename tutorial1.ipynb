# %% [markdown]
# BASIC OF PYTHON

# %% [markdown]
# In this video we will discuss about
# *Various datatypes in python
# *variable
# *variables assignment
# *print formatting

# %% [markdown]
# Various datatypes in python

# %% [markdown]
# 1-NUMBERS

# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
type(54)
# Out:
# int

# %% [markdown]
# ## Variable Assignment

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
a='Akshara Gupta'
type(a)
# Out:
# str

# %%
#printing strings
print("hello")
# Out:
# hello

# %%
first_name='Akshara'
last_name='Gupta'

# %%
print(f"My first name is{first_name} and my last name is {last_name}")
# Out:
# My first name isAkshara and my last name is Gupta

# %%
len(first_name)
# Out:
# 7
